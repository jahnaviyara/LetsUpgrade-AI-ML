# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_excel("general_data.xlsx", sheet_name = 0)

# %%
dataset1 = dataset.head(50)

# %%
sns.countplot(x = "Age", hue = "Attrition", data = dataset)

# %% [markdown]
# __Hypothesis 1__
# From the above plot we can conlcude that:

# %% [markdown]
# Mean age of a person taking attrition is 36.
# __Null Hypothesis H0 : µ = 36.
# __Alternative Hypothhesis H1 : µ ≠ 36

# %% [markdown]
# __Hypothesis 2__

# %%
sns.countplot(x = "BusinessTravel", hue = "Attrition", data = dataset)

# %% [markdown]
# Persons who travel rarely have high attrition rate
# __Null Hypothesis H0 : µ = Travel Rarely
# __Alternative Hypothesis H1 :µ ≠ Travel Rarely

# %% [markdown]
# __Hypothesis 3__

# %%
sns.countplot(x = "Department",hue = "Attrition",data = dataset)

# %% [markdown]
# Persons who work in Research and  Development Department have high attrition rate.
# __Null Hypothesis H0:µ = Research and Development Department
# __Alternative Hypothesis H1:µ ≠ Research and Development Depertment

# %% [markdown]
# __Hypothesis 4__

# %%
sns.countplot(x = "DistanceFromHome", hue = "Attrition",data = dataset)

# %% [markdown]
# Persons whose distance is greater than 10 have low attrition rate
# __Null Hypothesis H0:µ > 10
# __Alternative Hypothesis H1:µ <= 10

# %% [markdown]
# __Hypothesis 5__

# %%
sns.countplot(x = "Education", hue = "Attrition",data = dataset)

# %% [markdown]
# Persons whose education level is not equal to 3 have low attrition rate
# __Null Hypothesis H0:µ ≠ 3
# __Alternative Hypothesis H1:µ = 3

# %% [markdown]
# __Hypothesis 6__

# %%
sns.countplot(x = "JobLevel", hue = "Attrition",data = dataset)

# %% [markdown]
# person whose job level is  less than or equal to 2 have high attrition rate
# __Null Hypothesis H0:µ <= 2
# __Alternative Hypothesis H1:µ > 2

# %% [markdown]
# __Hypothesis 7__

# %%
sns.countplot(x = "NumCompaniesWorked",hue = "Attrition",data = dataset)

# %% [markdown]
# Person who worked in 1 company have high attrition rate
# __Null Hypothesis H0: µ = 1
# __Alternative Hypothesis H1 :µ ≠ 1

# %% [markdown]
# __Hypothesis 8__

# %%
sns.countplot(x = "PercentSalaryHike",hue = "Attrition",data = dataset)

# %% [markdown]
# Persons whose salaryhike percent is greater than or equal to 15 have low attrition rate
# __NullHypothesis H0 : µ >= 15
# __Alternative Hypothesis H1 : µ < 15

# %% [markdown]
# __Hypothesis 9__

# %%
sns.countplot(x = "StockOptionLevel",hue = "Attrition",data = dataset)

# %% [markdown]
# Persons whose StockOption Level is 0 have high attrition rate
# __Null Hypothesis H0 : µ = 0
# __Alternative Hypothesis H1 : µ ≠ 0

# %% [markdown]
# __Hypothesis 10__

# %%
sns.countplot(x = "TrainingTimesLastYear",hue = "Attrition",data = dataset)

# %% [markdown]
# Persons whose training time last year is 2 have high attrition rate
# __Null Hypothesis H0 : µ = 2
# __Alternative Hypothesis H1 :  µ ≠ 2
